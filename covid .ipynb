# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-datasets" data-toc-modified-id="Import-datasets-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import datasets</a></span><ul class="toc-item"><li><span><a href="#Worldometer-data" data-toc-modified-id="Worldometer-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Worldometer data</a></span></li><li><span><a href="#Day-wise---whole-world" data-toc-modified-id="Day-wise---whole-world-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Day wise - whole world</a></span></li><li><span><a href="#Cumulative-day-wise-for-each-country" data-toc-modified-id="Cumulative-day-wise-for-each-country-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Cumulative day wise for each country</a></span></li><li><span><a href="#Day-wise---countries-separately" data-toc-modified-id="Day-wise---countries-separately-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Day wise - countries separately</a></span></li></ul></li><li><span><a href="#Violin-plots---discretized-test/1000-and-death/confirmed" data-toc-modified-id="Violin-plots---discretized-test/1000-and-death/confirmed-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Violin plots - discretized test/1000 and death/confirmed</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Import datasets

# %% [markdown]
# ## Worldometer data

# %%
file = open('covid/worldometer_data.csv')
worldometer = pd.read_csv('covid/worldometer_data.csv')
file.close()
worldometer.fillna(0, inplace=True)
worldometer.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       0.0
# 1         Brazil  South America  2.127107e+08     2917562       0.0
# 2          India           Asia  1.381345e+09     2025409       0.0
# 3         Russia         Europe  1.459409e+08      871894       0.0
# 4   South Africa         Africa  5.938157e+07      538184       0.0
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        0.0       2576668.0           0.0    2292707.0
# 1      98644.0        0.0       2047660.0           0.0     771258.0
# 2      41638.0        0.0       1377384.0           0.0     606387.0
# 3      14606.0        0.0        676357.0           0.0     180931.0
# 4       9604.0        0.0        387316.0           0.0     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
worldometer["WHO Region"].unique()
# Out:
# array(['Americas', 'South-EastAsia', 'Europe', 'Africa',
#        'EasternMediterranean', 'WesternPacific', 0], dtype=object)

# %%
worldometer = worldometer.drop("WHO Region", 1)
worldometer = pd.merge(worldometer, new_df, on='Country/Region')
worldometer["WHO Region"].unique()
# Out:
# array(['Americas', 'South-East Asia', 'Europe', 'Africa',
#        'Eastern Mediterranean', 'Western Pacific'], dtype=object)

# %%
worldometer.shape
# Out:
# (209, 16)

# %%
worldometer.describe()
# Out:
#          Population    TotalCases     NewCases    TotalDeaths   NewDeaths  \
# count  2.090000e+02  2.090000e+02   209.000000     209.000000  209.000000
# mean   3.026996e+07  9.171850e+04    37.904306    3411.516746    4.306220
# std    1.045351e+08  4.325867e+05   463.953776   14728.994111   56.894234
# min    0.000000e+00  1.000000e+01     0.000000       0.000000    0.000000
# 25%    8.970950e+05  7.120000e+02     0.000000      12.000000    0.000000
# 50%    6.942854e+06  4.491000e+03     0.000000      70.000000    0.000000
# 75%    2.552886e+07  3.689600e+04     0.000000     600.000000    0.000000
# max    1.381345e+09  5.032179e+06  6590.000000  162804.000000  819.000000
#
#        TotalRecovered  NewRecovered   ActiveCases  Serious,Critical  \
# count    2.090000e+02    209.000000  2.090000e+02        209.000000
# mean     5.775211e+04     24.488038  2.713487e+04        311.942584
# std      2.543468e+05    293.291420  1.729872e+05       1583.835315
# ...

# %% [markdown]
# ## Day wise - whole world

# %%
file = open('covid/day_wise.csv')
day_wise = pd.read_csv('covid/day_wise.csv')
file.close()
day_wise.fillna(0, inplace=True)
day_wise.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
day_wise.shape
# Out:
# (188, 12)

# %%
day_wise.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# ...

# %% [markdown]
# ## Cumulative day wise for each country

# %%
file = open('covid/covid_19_clean_complete.csv')
clean_complete = pd.read_csv('covid/covid_19_clean_complete.csv')
file.close()
clean_complete.fillna(0, inplace=True)
clean_complete.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0              0    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1              0        Albania  41.15330  20.168300  2020-01-22          0
# 2              0        Algeria  28.03390   1.659600  2020-01-22          0
# 3              0        Andorra  42.50630   1.521800  2020-01-22          0
# 4              0         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
clean_complete.shape
# Out:
# (49068, 10)

# %%
clean_complete.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %% [markdown]
# ## Day wise - countries separately

# %%
file = open('covid/full_grouped.csv')
full_grouped = pd.read_csv('covid/full_grouped.csv')
file.close()
full_grouped.fillna(0, inplace=True)
full_grouped.head()
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa

# %%
full_grouped.shape
# Out:
# (35156, 10)

# %%
full_grouped.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active    New cases  \
# count  3.515600e+04   35156.000000  3.515600e+04  3.515600e+04  35156.00000
# mean   2.356663e+04    1234.068239  1.104813e+04  1.128443e+04    469.36375
# std    1.499818e+05    7437.238354  6.454640e+04  8.997149e+04   3005.86754
# min    0.000000e+00       0.000000  0.000000e+00 -2.000000e+00      0.00000
# 25%    1.000000e+00       0.000000  0.000000e+00  0.000000e+00      0.00000
# 50%    2.500000e+02       4.000000  3.300000e+01  8.500000e+01      2.00000
# 75%    3.640250e+03      78.250000  1.286250e+03  1.454000e+03     75.00000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  77255.00000
#
#          New deaths  New recovered
# count  35156.000000   35156.000000
# mean      18.603339     269.315593
# std      115.706351    2068.063852
# min    -1918.000000  -16298.000000
# 25%        0.000000       0.000000
# 50%        0.000000       0.000000
# ...

# %%
full_grouped["WHO Region"].unique()
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %%
full_grouped["Country/Region"].unique().shape
# Out:
# (187,)

# %%
new_df = full_grouped[["Country/Region", "WHO Region"]].reset_index(drop=True)
new_df.head()
# Out:
#   Country/Region             WHO Region
# 0    Afghanistan  Eastern Mediterranean
# 1        Albania                 Europe
# 2        Algeria                 Africa
# 3        Andorra                 Europe
# 4         Angola                 Africa

# %% [markdown]
# # Violin plots - discretized test/1000 and death/confirmed
